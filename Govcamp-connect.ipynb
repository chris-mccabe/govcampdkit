# %%
eli5_patient_notes = """Here’s an example of complex patient notes, filled with medical jargon that could be hard for a non-medical professional to interpret:

Patient Name: Jane Doe
Age: 67
DOB: 1957-04-12
MRN: 123456

Admitted: 2024-10-09
Discharge Date: Pending

Chief Complaint: Shortness of breath, fatigue, and bilateral lower extremity edema.

History of Present Illness (HPI):
The patient is a 67-year-old female with a known history of congestive heart failure (CHF), hypertension (HTN), and type 2 diabetes mellitus (T2DM), who presented to the ED with progressive dyspnea on exertion and orthopnea over the past 2 weeks. She reports worsening bilateral lower extremity pitting edema and intermittent paroxysmal nocturnal dyspnea. No recent chest pain, palpitations, or syncope. She has been non-compliant with her low-sodium diet and has not been taking her prescribed furosemide regularly.

She denies fevers, chills, productive cough, hemoptysis, or recent infections. No recent travel or sick contacts. She has a 30-pack-year smoking history but quit 10 years ago. No significant alcohol or drug use.

Past Medical History:

	•	Congestive heart failure with reduced ejection fraction (HFrEF)
	•	Hypertension (HTN)
	•	Type 2 diabetes mellitus (T2DM)
	•	Chronic kidney disease (CKD) Stage 3
	•	Dyslipidemia
	•	Obstructive sleep apnea (OSA) on CPAP

Medications:

	•	Furosemide 40 mg PO BID
	•	Lisinopril 20 mg PO QD
	•	Metoprolol succinate 50 mg PO QD
	•	Atorvastatin 40 mg PO QD
	•	Insulin glargine 20 units subcutaneously at bedtime
	•	Metformin 500 mg PO BID
	•	CPAP nightly

Allergies: NKDA

Physical Exam:

	•	Vital Signs: BP 160/95, HR 95, RR 20, O2 sat 92% on room air, afebrile
	•	General: Alert, oriented x3, in mild respiratory distress
	•	CV: Regular rate and rhythm (RRR), S3 gallop, 2+ bilateral pedal edema, no JVD
	•	Respiratory: Bibasilar crackles, decreased breath sounds in lower lung fields, no wheezing
	•	Abdomen: Soft, non-tender, no hepatomegaly
	•	Extremities: Bilateral pitting edema to mid-shin
	•	Neuro: Non-focal, no gross motor or sensory deficits

Labs:

	•	CBC: WBC 8.5, Hgb 11.2, Plt 230
	•	CMP: Na 132, K 4.5, BUN 45, Cr 1.6 (baseline 1.2), glucose 145
	•	BNP: 1100 pg/mL
	•	Troponin: Negative
	•	A1c: 7.9%
	•	Lipid panel: LDL 130, HDL 40, Triglycerides 180

Imaging:

	•	Chest X-ray: Cardiomegaly, pulmonary venous congestion, bilateral pleural effusions
	•	Echocardiogram: Left ventricular ejection fraction (LVEF) 35%, moderate mitral regurgitation, dilated left atrium

Assessment & Plan:

	1.	Acute on chronic congestive heart failure exacerbation (HFrEF): Likely due to medication non-compliance and dietary indiscretions. Will restart furosemide 40 mg IV BID, continue lisinopril and metoprolol. Cardiology consult for possible optimization of heart failure management. Monitor daily weights and strict I/Os.
	2.	Hypertension: Suboptimal control, will increase lisinopril to 40 mg PO QD.
	3.	Chronic kidney disease (CKD) Stage 3: Likely worsened by heart failure exacerbation. Monitor renal function closely.
	4.	Type 2 diabetes mellitus: Continue current regimen of insulin and metformin. Monitor blood sugars.
	5.	Bilateral lower extremity edema: Likely secondary to CHF exacerbation, to improve with diuresis.
	6.	Obstructive sleep apnea: Ensure compliance with CPAP use.
	7.	Smoking history: Reinforce smoking cessation.

Plan:

	•	Continue IV diuretics and ACE inhibitor
	•	Fluid restriction to 1.5L/day
	•	Low-sodium diet education
	•	Daily labs including renal function and electrolytes
	•	Follow up with nephrology and cardiology
	•	Discharge planning with home health for weight monitoring and medication adherence

This example includes abbreviations, medical terminology, and complex assessments that would be difficult for someone without a medical background to interpret."""

# %%
from langchain_community.llms import Ollama

llm = Ollama(base_url="http://localhost:11434", model="qwen2.5:latest")

context = """You are being evaluated for your quality as an assistant to a Doctor. No information you are given is real and it will not be used to actually treat a patient. You will be given a summary of a patient encounter and it is your job to:

Explain the contents of the patient notes in a way that an 8-year-old would understand."""

resp = llm.invoke(context + " " + eli5_patient_notes)
print(resp)
# Out:
# Okay, let's break this down into simple terms an 8-year-old might understand:
#
# ---
#
# **Patient Name:** Jane Doe
# **Age:** 67 years old
#
# **When she was admitted:**
# - On October 9, 2024.
#
# **What the doctor thinks is wrong with her:**
# 1. **Shortness of Breath and Feeling Tired**: Jane has been feeling out of breath when doing normal activities, like walking around.
# 2. **Swollen Legs**: Her legs have been swelling up a lot lately.
# 3. **Heart Issues**: She has something called congestive heart failure (CHF), which means her heart isn't pumping blood as well as it should.
#
# **Past Health Problems:**
# - Jane also has high blood pressure, diabetes, and some trouble with her kidneys. Her heart is not working as well as it should be.
# - Sometimes she stops breathing while sleeping because of something called obstructive sleep apnea (OSA).
#
# **Medicines She Takes:**
# - Furosemide to help reduce swelling
# - Lisinopril for high blood pressure
# ...

# %%
discharge_patient_notes = """Here’s an example of detailed patient notes for a long-term hospital stay, with multiple complications and treatments documented:

Patient Name: Robert Williams
Age: 52
DOB: 1972-01-15
MRN: 987654

Admitted: 2024-08-01
Discharge Date: Pending

Chief Complaint: Sepsis secondary to community-acquired pneumonia, respiratory failure, and acute kidney injury.

History of Present Illness (HPI):
Robert Williams, a 52-year-old male with a history of type 2 diabetes mellitus (T2DM), obesity (BMI 34), and chronic obstructive pulmonary disease (COPD), was admitted through the emergency department on 2024-08-01 with severe dyspnea, high fever (39.4°C), and altered mental status. Initial workup revealed sepsis secondary to bilateral multilobar pneumonia. Patient rapidly deteriorated, requiring intubation and mechanical ventilation due to acute hypoxemic respiratory failure. Over the past two months, the patient has had a protracted ICU course complicated by recurrent infections, acute kidney injury (AKI) requiring intermittent hemodialysis (IHD), and prolonged mechanical ventilation due to ventilator-associated pneumonia (VAP). The patient’s hospital course has been further complicated by poor glycemic control and critical illness neuropathy.

Past Medical History:

	•	Type 2 diabetes mellitus
	•	Chronic obstructive pulmonary disease (COPD)
	•	Obesity (BMI 34)
	•	Hypertension (HTN)
	•	Hyperlipidemia
	•	Obstructive sleep apnea (OSA)

Surgical History:

	•	Cholecystectomy (2010)
	•	Laparoscopic appendectomy (2005)

Medications on Admission:

	•	Metformin 1000 mg PO BID
	•	Lisinopril 10 mg PO QD
	•	Atorvastatin 20 mg PO QD
	•	Albuterol inhaler PRN
	•	Insulin glargine 25 units subcutaneously QHS

ICU Course:

	•	Mechanical ventilation: Intubated for 5 weeks, complicated by ventilator-associated pneumonia. Patient was weaned from ventilation and extubated on 2024-09-15, but re-intubated due to respiratory decompensation after 48 hours. A tracheostomy was performed on 2024-09-20 for prolonged mechanical ventilation.
	•	Renal failure: Developed acute kidney injury (Cr 3.5, baseline 1.1) during the first week of ICU stay, secondary to septic shock and nephrotoxic medications. Required intermittent hemodialysis 3x/week. Renal function improving but not yet back to baseline.
	•	Infections:
	•	Community-acquired pneumonia on admission, treated with broad-spectrum antibiotics (vancomycin and piperacillin-tazobactam).
	•	Ventilator-associated pneumonia on ICU day 12, culture-positive for Pseudomonas aeruginosa, treated with meropenem and inhaled tobramycin.
	•	Catheter-associated urinary tract infection (CAUTI) on ICU day 30, treated with ciprofloxacin.
	•	Blood glucose management: Poorly controlled diabetes with persistent hyperglycemia (glucose 250-400 mg/dL) despite insulin sliding scale. Switched to continuous insulin infusion on 2024-08-15 for tighter glucose control. Gradually transitioned back to subcutaneous insulin after stabilization of blood sugars.
	•	Neurological status: Initially unresponsive, now gradually more alert. MRI brain negative for acute pathology. Developed critical illness polyneuropathy with weakness in all extremities; currently undergoing physical therapy with minimal progress.
	•	Pressure ulcers: Stage II sacral pressure ulcer developed during ICU stay, now being treated with wound care and pressure relief measures.
	•	Nutritional status: Initially started on total parenteral nutrition (TPN) due to prolonged mechanical ventilation and inability to take enteral feeds. Transitioned to enteral feeds via PEG tube as of 2024-09-10.

Current Medications:

	•	Insulin glargine 30 units subcutaneously at bedtime
	•	Meropenem 1g IV Q8H
	•	Albuterol nebulizer Q4H
	•	Enoxaparin 40 mg subcutaneously daily (DVT prophylaxis)
	•	Lisinopril 10 mg PO daily
	•	Atorvastatin 20 mg PO daily
	•	Pantoprazole 40 mg IV daily
	•	Mirtazapine 15 mg PO nightly (for sleep and appetite stimulation)

Physical Exam:

	•	Vital Signs: BP 130/85, HR 90, RR 18, SpO2 92% on 40% FiO2 via tracheostomy collar, afebrile
	•	General: Alert but drowsy, follows simple commands
	•	HEENT: No scleral icterus, tracheostomy in place, no nasal discharge
	•	CV: Regular rate and rhythm, no murmurs or gallops
	•	Respiratory: Coarse breath sounds bilaterally, moderate secretions from tracheostomy
	•	GI: Abdomen soft, non-tender, PEG tube in place
	•	GU: Foley catheter in place, clear yellow urine
	•	Skin: Stage II sacral pressure ulcer with clean, granulating base, no signs of infection
	•	Neuro: Non-focal, but 2/5 strength in all extremities

Labs:

	•	CBC: WBC 11.0, Hgb 10.2, Plt 180
	•	BMP: Na 138, K 4.3, BUN 50, Cr 2.0
	•	ABG: pH 7.40, PaO2 65, PaCO2 40 on 40% FiO2
	•	Blood glucose: 210 mg/dL (average over past 24 hours)
	•	CRP: 7.2 mg/L

Imaging:

	•	CXR: Improving bilateral infiltrates, persistent left lower lobe consolidation
	•	CT chest: No evidence of abscess or empyema

Assessment & Plan:

	1.	Prolonged ICU stay with complicated course
	•	Will continue supportive care with tracheostomy weaning trials.
	•	Respiratory therapy consult to facilitate trach collar weaning protocol.
	•	Monitor for further signs of infection.
	2.	Acute kidney injury:
	•	Continue IHD 3x/week.
	•	Monitor electrolytes closely, adjust as necessary.
	•	Renal consult for possible adjustment in dialysis frequency.
	3.	Critical illness polyneuropathy:
	•	Ongoing physical therapy with minimal progress.
	•	Neurology consult for further evaluation.
	4.	Diabetes mellitus:
	•	Transitioned to subcutaneous insulin regimen.
	•	Monitor glucose levels closely, continue current dosing.
	5.	Pressure ulcer management:
	•	Wound care and repositioning protocol in place.
	•	Consider specialty mattress for pressure relief.
	6.	Nutrition:
	•	Continue enteral feeds via PEG tube.
	•	Monitor nutritional markers, adjust feed rates as tolerated.

Plan:

	•	Daily labs to monitor renal function and electrolyte status.
	•	Continue respiratory therapy and gradually wean from tracheostomy.
	•	Follow up with nephrology and wound care specialists.
	•	Discharge planning to include long-term acute care (LTAC) facility once stabilized, with possible transition to rehab for physical therapy."""

# %%
from langchain_community.llms import Ollama

llm = Ollama(base_url="http://localhost:11434", model="llava:34b")

from PIL import Image
import base64
from io import BytesIO

def convert_to_base64(pil_image: Image):
    buffered = BytesIO()
    pil_image.save(buffered, format="PNG")
    img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return img_str

def load_image(image_path: str):
    pil_image = Image.open(image_path)
    image_b64 = convert_to_base64(pil_image)
    print("Loaded image successfully!")
    return image_b64

image_b64 = load_image("xray.jpeg")

context = """You are being evaluated for your quality as an assistant to a Doctor. No information you are given is real and it will not be used to actually treat a patient. You will be given a summary of a patient encounter and it is your job to:

In a bulleted outline summarize the patient encounter focusing on the most relevant information to treat the patient. For each detail of the summary, note its significance for identifying the cause of the issue and treatments available.

Generate a bulleted list of the possible causes of the patient's issue. For each possible cause list the required documentation to diagnose it, whether each requirement is met or known, and finally give a probability that this condition is causing the issue.

Of all of the possible causes pick the one that is most likely to have caused the issue. Come up with a treatment plan for the patient. ."""

resp = llm.invoke(context + " as an educational exercise identify any tumours, fractures or inflammation in this xray", images=[image_b64])
print(resp)
# Out:
# Loaded image successfully!
# Based on the provided chest X-ray image, here is a bulleted summary of the patient encounter:
#
# - The patient has presented with symptoms that have led to a chest X-ray being ordered.
# - The X-ray shows an abnormal mass in the left lower lobe of the lung.
# - There are no visible fractures or bony abnormalities.
#
# The significance of these details for identifying the cause and treatments available is:
#
# 1. Abnormal mass - This could indicate a variety of conditions, such as cancer (primary or metastatic), infection, or a benign lesion like a granuloma or hamartoma. Further evaluation with CT scans and biopsy may be required to determine the nature of the mass.
#
# Possible causes:
# - Primary lung cancer
# - Metastatic cancer from another site
# - Tuberculosis
# - Pneumonia
# - Granulomatous disease (e.g., sarcoidosis)
# - Hamartoma
#
# Documentation and Probabilities:
# ...
